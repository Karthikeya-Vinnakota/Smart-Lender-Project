# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Remove ID column
df = df.drop('Loan_ID', axis=1)

# Separate X and y
X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

# Convert categorical features
X = pd.get_dummies(X, drop_first=True)

# Scale features
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print(X_scaled.head())
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.072991          -0.554487         NaN          0.276642
# 1        -0.134412          -0.038732   -0.215309          0.276642
# 2        -0.393747          -0.554487   -0.940328          0.276642
# 3        -0.462062           0.251980   -0.308860          0.276642
# 4         0.097728          -0.554487   -0.063289          0.276642
#
#    Credit_History  Gender_Male  Married_Yes  Dependents_1  Dependents_2  \
# 0        0.432861     0.505592    -1.357421     -0.446339     -0.443713
# 1        0.432861     0.505592     0.736691      2.240448     -0.443713
# 2        0.432861     0.505592     0.736691     -0.446339     -0.443713
# 3        0.432861     0.505592     0.736691     -0.446339     -0.443713
# 4        0.432861     0.505592    -1.357421     -0.446339     -0.443713
#
#    Dependents_3+  Education_Not Graduate  Self_Employed_Yes  \
# 0      -0.300975               -0.528362          -0.392601
# 1      -0.300975               -0.528362          -0.392601
# 2      -0.300975               -0.528362           2.547117
# 3      -0.300975                1.892641          -0.392601
# 4      -0.300975               -0.528362          -0.392601
#
#    Property_Area_Semiurban  Property_Area_Urban
# 0                -0.782016             1.428147
# 1                -0.782016            -0.700208
# 2                -0.782016             1.428147
# 3                -0.782016             1.428147
# 4                -0.782016             1.428147
